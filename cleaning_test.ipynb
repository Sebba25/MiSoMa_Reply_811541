# %%
import pandas as pd
# import cleaned dataset from Data/.cleaning_cache/attivazioniCessazioni.cleaned.csv
df = pd.read_csv("Data/.cleaning_cache/attivazioniCessazioni/attivazioniCessazioni.cleaned.csv")
df2 = pd.read_csv("Data/attivazioniCessazioni.csv")

# %%
df
# Out:
#                             _id  mese  anno  codice_ente  \
# 0      6852caf7205349164bebcd69  11.0  2023         19.0
# 1      6852caff6555da0907a40857   7.0  2023       2020.0
# 2      6852caef205349164bea2a6e   8.0  2021       2020.0
# 3      6852cb029952cb647ef389e4   4.0  2023       2020.0
# 4      6852cae9205349164be90859   6.0  2023         22.0
# ...                         ...   ...   ...          ...
# 20097  6852caf6205349164beb8cb1   7.0  2023         10.0
# 20098  6852caed205349164be99f25   4.0  2023         10.0
# 20099  6852cafe205349164bec13dd   5.0  2023          9.0
# 20100  6852caee205349164be9faee   9.0  2023         14.0
# 20101  6852caf2205349164beacb96   8.0  2023         32.0
#
#                                        descrizione_ente provincia_sede  \
# 0                       ministero universita' e ricerca             to
# 1      ministero dell'interno - dipartimento della p.s.             bt
# ...

# %%
#distinc Year value
df["anno"].unique()
# Out:
# array([2023, 2021, 2024,   23, 2022,   24])

# %%
df2["anno"].unique()
# Out:
# <ArrowStringArray>
# [     '2023',      '2021',      '2024',        '23',     '2024.',      '2022',
#      '2023.', 'anno 2024', 'anno 2023',        '24']
# Length: 10, dtype: str

# %%
df2[df2["anno"] == '23'].shape[0]
# Out:
# 99

# %%
#count anno = 23
df[df["anno"] == 23].shape[0]
# Out:
# 99
